# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
#Reading Input Data
file_path = r"C:/Users/Mangar William/Desktop/K-Mean Clustering Spending.csv"
data = pd.read_csv(file_path)

# %%
data
# Out:
#    Income  Spending  cluster
# 0      80      24.0        1
# 1      85      25.5        0
# 2      87      26.1        0
# 3      75      22.5        1
# 4      78      23.4        1

# %%
print(data.head())
# Out:
#    Income  Spending
# 0      80      24.0
# 1      85      25.5
# 2      87      26.1
# 3      75      22.5
# 4      78      23.4

# %%
#plot data points
plt.figure(figsize=(10,6))
plt.scatter(data['Income'],data['Spending'])
plt.xlabel('Income')
plt.ylabel('Expense')
plt.title('Customer Data')
# Out:
# Text(0.5, 1.0, 'Customer Data')

# %%
import os
os.environ["OMP_NUM_THREADS"] = "1"

# %%
individual_clustering_score =[]
for i in range(1, 5):
    kmeans =KMeans(n_clusters = i, init = 'random', random_state = 42)
    kmeans.fit(data)
    individual_clustering_score.append(kmeans.inertia_)

plt.figure(figsize=(10,6))
plt.plot(range(1, 5), individual_clustering_score)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('Clustering Score')
plt.show()
# Out:
# C:\Users\Mangar William\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Mangar William\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Mangar William\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
individual_clustering_score
# Out:
# [106.82000000000001, 15.986666666666666, 4.360000000000002, 2.180000000000001]

# %%
import os
os.environ["OMP_NUM_THREADS"] = "1"

# %%
#fit the model and predict
kmeans = KMeans(n_clusters = 2, random_state =42)

kmeans.fit(data)

pred = kmeans.predict(data)

pred
# Out:
# C:\Users\Mangar William\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# array([1, 0, 0, 1, 1])

# %%
data['cluster'] = pd.DataFrame(pred, columns=['cluster'])  #adding cluster column to mean data

# %%
data.head()
# Out:
#    Income  Spending  cluster
# 0      80      24.0        1
# 1      85      25.5        0
# 2      87      26.1        0
# 3      75      22.5        1
# 4      78      23.4        1

# %%
import seaborn as sns

# 'hue' argument to provide a factor variable
sns.lmplot(x="Income", y="Spending", data=data, fit_reg=False, hue='cluster', legend=True)

plt.legend(loc='lower right')
plt.show()

# %%
kmeans.cluster_centers_
# Out:
# array([[86.        , 25.8       ],
#        [77.66666667, 23.3       ]])

# %% [markdown]
# ## Interview Questions on K-means
